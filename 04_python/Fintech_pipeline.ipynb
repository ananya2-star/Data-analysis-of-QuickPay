# %%
#import libraries
import pandas as pd
import json
import os

# %%
# 1. Load both files
ledger = pd.read_csv('ledger.csv')
gateway = pd.read_csv('gateway.csv')

# %%
# 2. Check duplicates and null
print('Duplicates in ledger:')
ledger.duplicated().sum()
print('Duplicates in gateway:')
gateway.duplicated().sum()
# Out:
# Duplicates in ledger:
# Duplicates in gateway:
# np.int64(0)

# %%
# Check for null values
print('Null values in ledger:')
display(ledger.isnull().sum())

print('\nNull values in gateway:')
display(gateway.isnull().sum())
# Out:
# Null values in ledger:
# transaction_id      0
# transaction_date    0
# merchant_id         0
# amount_usd          0
# status              0
# payment_method      0
# dtype: int64
# Null values in gateway:
# transaction_id      0
# transaction_date    0
# merchant_id         0
# amount_usd          0
# status              0
# payment_method      0
# dtype: int64

# %%
# 3. identify records missing in gateway
display(missing_in_gateway)
# Out:
#   transaction_id transaction_date_ledger merchant_id_ledger  \
# 3           R004              2026-03-02               M003
# 9           R010              2026-03-05               M004
#
#    amount_usd_ledger status_ledger payment_method_ledger  \
# 3             2100.0       success                  Card
# 9             2500.0       success                Wallet
#
#   transaction_date_gateway merchant_id_gateway  amount_usd_gateway  \
# 3                      NaN                 NaN                 NaN
# 9                      NaN                 NaN                 NaN
#
#   status_gateway payment_method_gateway     _merge
# 3            NaN                    NaN  left_only
# 9            NaN                    NaN  left_only

# %%
# 4. identify records missing in ledger
display(missing_in_ledger)
# Out:
#    transaction_id transaction_date_ledger merchant_id_ledger  \
# 10           R011                     NaN                NaN
#
#     amount_usd_ledger status_ledger payment_method_ledger  \
# 10                NaN           NaN                   NaN
#
#    transaction_date_gateway merchant_id_gateway  amount_usd_gateway  \
# 10               05-03-2026                M003              1800.0
#
#    status_gateway payment_method_gateway      _merge
# 10        success                   Card  right_only

# %%
# 5. Identify amount mismatches
display(amount_mismatches)
# Out:
#   transaction_id transaction_date_ledger merchant_id_ledger  \
# 1           R002              2026-03-01               M002
# 7           R008              2026-03-04               M001
#
#    amount_usd_ledger status_ledger payment_method_ledger  \
# 1              850.0       success                  Card
# 7              640.0       success                  Card
#
#   transaction_date_gateway merchant_id_gateway  amount_usd_gateway  \
# 1               01-03-2026                M002               900.0
# 7               04-03-2026                M001               600.0
#
#   status_gateway payment_method_gateway _merge
# 1        success                   Card   both
# 7        success                   Card   both

# %%
# 6. identify status mismatches
display(status_mismatches)
# Out:
#   transaction_id transaction_date_ledger merchant_id_ledger  \
# 4           R005              2026-03-03               M004
#
#    amount_usd_ledger status_ledger payment_method_ledger  \
# 4             7200.0       success                  Card
#
#   transaction_date_gateway merchant_id_gateway  amount_usd_gateway  \
# 4               03-03-2026                M004              7200.0
#
#   status_gateway payment_method_gateway _merge
# 4         failed                   Card   both

# %%
# 7. build a final reconciliation report
display(reconciliation_report)
# Out:
#    transaction_id transaction_date_ledger merchant_id_ledger  \
# 0            R001              2026-03-01               M001
# 1            R002              2026-03-01               M002
# 2            R003              2026-03-02               M001
# 3            R004              2026-03-02               M003
# 4            R005              2026-03-03               M004
# 5            R006              2026-03-03               M002
# 6            R007              2026-03-04               M005
# 7            R008              2026-03-04               M001
# 8            R009              2026-03-05               M002
# 9            R010              2026-03-05               M004
# 10           R011                     NaN                NaN
#
#     amount_usd_ledger status_ledger payment_method_ledger  \
# 0              1200.0       success                   UPI
# 1               850.0       success                  Card
# ...

# %% [markdown]
# ## Summary Metrics

# %%
# 8. generate summary metrics
display(summary)
# Out:
# {'total_ledger_records': 10,
#  'total_gateway_records': 9,
#  'ledger_duplicates': 0,
#  'gateway_duplicates': 0,
#  'ledger_nulls': 0,
#  'gateway_nulls': 0,
#  'missing_in_gateway': 2,
#  'missing_in_ledger': 1,
#  'amount_mismatches': 2,
#  'status_mismatches': 1,
#  'perfect_matches': 5}
